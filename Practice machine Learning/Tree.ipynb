# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv(r"C:\ProgramData\Ml_Data\drug_dt.csv")

# %%
mydata
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# 5     22   F  NORMAL        HIGH    8.607  drugX
# 6     49   F  NORMAL        HIGH   16.275  drugY
# 7     41   M     LOW        HIGH   11.037  drugC
# 8     60   M  NORMAL        HIGH   15.171  drugY
# 9     43   M     LOW      NORMAL   19.368  drugY
# 10    47   F     LOW        HIGH   11.767  drugC
# 11    34   F    HIGH      NORMAL   19.199  drugY
# 12    43   M     LOW        HIGH   15.376  drugY
# 13    74   F     LOW        HIGH   20.942  drugY
# 14    50   F  NORMAL        HIGH   12.703  drugX
# 15    16   F    HIGH      NORMAL   15.516  drugY
# 16    69   M     LOW      NORMAL   11.455  drugX
# 17    43   M    HIGH        HIGH   13.972  drugA
# ...

# %%
mydata.shape
# Out:
# (200, 6)

# %%
mydata.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
sns.countplot(x='Drug',hue='Sex',data=mydata)
plt.show()

# %%
mydata.Drug.value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %% [markdown]
# # Split

# %%
x = mydata.iloc[:,0:5]
y = mydata.iloc[:,5]

# %%
x.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K
# 0   23   F    HIGH        HIGH   25.355
# 1   47   M     LOW        HIGH   13.093
# 2   47   M     LOW        HIGH   10.114
# 3   28   F  NORMAL        HIGH    7.798
# 4   61   F     LOW        HIGH   18.043

# %%
x.Sex[x.Sex=="M"]=0
x.Sex[x.Sex=="F"]=1
x.BP[x.BP=="LOW"]=0
x.BP[x.BP=="NORMAL"]=1
x.BP[x.BP=="HIGH"]=2
x.Cholesterol[x.Cholesterol=="HIGH"]=2
x.Cholesterol[x.Cholesterol=="LOW"]=0
x.Cholesterol[x.Cholesterol=="NORMAL"]=1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# ...

# %%
x.head()
# Out:
#    Age Sex BP Cholesterol  Na_to_K
# 0   23   1  2           2   25.355
# 1   47   0  0           2   13.093
# 2   47   0  0           2   10.114
# 3   28   1  1           2    7.798
# 4   61   1  0           2   18.043

# %%
print("type of x "+str(type(x)))
print("type of y "+str(type(y)))
# Out:
# type of x <class 'pandas.core.frame.DataFrame'>
# type of y <class 'pandas.core.series.Series'>

# %%
xx=x.values
yy=x.values

# %%
print("type of xx "+str(type(xx)))
print("type of yy "+str(type(yy)))
# Out:
# type of xx <class 'numpy.ndarray'>
# type of yy <class 'numpy.ndarray'>

# %% [markdown]
# # split the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(xx,yy,test_size=0.30,random_state=101)

# %%
#model
from sklearn.tree import DecisionTreeClassifier

# %%
trainer = DecisionTreeClassifier(criterion='entropy',max_depth=4)

# %%
learner = trainer.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-5398a2f706e4> in <module>()
# ----> 1 learner = trainer.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     144
#     145         if is_classification:
# --> 146             check_classification_targets(y)
#     147             y = np.copy(y)
#     148
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...

# %% [markdown]
# # testing

# %%
YA = y_test
YP = learner.predict(x_test)

# %% [markdown]
# # ACC

# %%
from sklearn.matrics import jaccard_similarity_score,confusion_matrics

# %%
acc = accuracy_score(YA,YP)*100

# %%
acc

# %%
plt.plot(x_test,y_test,'go')
plt.plot(x_test,YP,'*r')
plt.xlabel("Input")
plt.xlabel("Output")
plt.legend(["ya,yp"])
plt.show()

# %% [markdown]
# # TREE VISUALIZATION
