# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mydata = pd.read_csv("C:\ProgramData\Ml_Data\FuelConsumptionCo2.csv")

# %%
mydata
# Out:
#       MODELYEAR          MAKE                        MODEL    VEHICLECLASS  \
# 0          2014         ACURA                          ILX         COMPACT
# 1          2014         ACURA                          ILX         COMPACT
# 2          2014         ACURA                   ILX HYBRID         COMPACT
# 3          2014         ACURA                      MDX 4WD     SUV - SMALL
# 4          2014         ACURA                      RDX AWD     SUV - SMALL
# 5          2014         ACURA                          RLX        MID-SIZE
# 6          2014         ACURA                           TL        MID-SIZE
# 7          2014         ACURA                       TL AWD        MID-SIZE
# 8          2014         ACURA                       TL AWD        MID-SIZE
# 9          2014         ACURA                          TSX         COMPACT
# 10         2014         ACURA                          TSX         COMPACT
# ...

# %%
mydata.head(5)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
mydata.keys()
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
# MODELYEAR                   1067 non-null int64
# MAKE                        1067 non-null object
# MODEL                       1067 non-null object
# VEHICLECLASS                1067 non-null object
# ENGINESIZE                  1067 non-null float64
# CYLINDERS                   1067 non-null int64
# TRANSMISSION                1067 non-null object
# FUELTYPE                    1067 non-null object
# FUELCONSUMPTION_CITY        1067 non-null float64
# FUELCONSUMPTION_HWY         1067 non-null float64
# FUELCONSUMPTION_COMB        1067 non-null float64
# FUELCONSUMPTION_COMB_MPG    1067 non-null int64
# CO2EMISSIONS                1067 non-null int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.4+ KB

# %%
#seperate input and output
x_input = mydata.iloc[:,2:12]

# %%
y_output = mydata.iloc[:,12]

# %%
x_input.head(1)
# Out:
#   MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0   ILX      COMPACT         2.0          4          AS5        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
#
#    FUELCONSUMPTION_COMB_MPG
# 0                        33

# %%
x_input.dtypes
# Out:
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# dtype: object

# %%
x_input_nu = mydata[['CYLINDERS','ENGINESIZE','CO2EMISSIONS','FUELCONSUMPTION_COMB']]

# %%
x_input_nu.head()
# Out:
#    CYLINDERS  ENGINESIZE  CO2EMISSIONS  FUELCONSUMPTION_COMB
# 0          4         2.0           196                   8.5
# 1          4         2.4           221                   9.6
# 2          4         1.5           136                   5.9
# 3          6         3.5           255                  11.1
# 4          6         3.5           244                  10.6

# %%
x_input_nu.hist(bins=50)
plt.show()

# %% [markdown]
# # PLOTTING FUELCONSUMPTION

# %%
plt.scatter(x_input_nu.FUELCONSUMPTION_COMB,y_output.values,color='blue')
plt.show()

# %% [markdown]
# # PLOTTING ENGINESIZE

# %%
plt.scatter(x_input_nu.ENGINESIZE,y_output.values,color='red')
plt.show()

# %% [markdown]
# # PLOTTING CYLINDERS

# %%
plt.scatter(x_input_nu.CYLINDERS,y_output.values,color='green')
plt.show()

# %% [markdown]
# # PREDICTING CO2EMISSION, ENGINE SIZE

# %%
xx = mydata.ENGINESIZE
yy = mydata.CO2EMISSIONS

# %%
print("type of xx IS {} type of yy is {}".format(type(xx),type(yy)))
# Out:
# type of xx IS <class 'pandas.core.series.Series'> type of yy is <class 'pandas.core.series.Series'>

# %%
#Converting series into numpy array
xs = xx.values.reshape(len(xx),1)
ys = yy.values.reshape(len(yy),1)

# %%
print("type of xx IS {} type of ys is {}".format(type(xs),type(ys)))
# Out:
# type of xx IS <class 'numpy.ndarray'> type of ys is <class 'numpy.ndarray'>

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # spliting in train and test

# %%
x_train,x_test,y_train,y_test = train_test_split(xs,ys,test_size=.30,random_state=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a97cdad2b89d> in <module>()
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(xs,ys,test_size=.30,random_state=100)
#
# NameError: name 'train_test_split' is not defined

# %%
print("sample of x-train {} and x_test {} ".format(x_train.shape,x_test.shape))
print("sample of y-train {} and y_test {} ".format(y_train.shape,y_test.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca994df917dd> in <module>()
# ----> 1 print("sample of x-train {} and x_test {} ".format(x_train.shape,x_test.shape))
#       2 print("sample of y-train {} and y_test {} ".format(y_train.shape,y_test.shape))
#
# NameError: name 'x_train' is not defined

# %%
#x_train

# %% [markdown]
# # Training

# %%
from sklearn.linear_model import LinearRegression

# %%
trainer = LinearRegression(fit_intercept=True)

# %%
learner = trainer.fit(x_train,y_train)

# %% [markdown]
# # Test

# %%
ya = y_test
yp = learner.predict(x_test)

# %%
learner.predict([[12]])
# Out:
# array([[ 598.31340739]])

# %%
learner.intercept_
# Out:
# array([ 125.17049357])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
error = np.sqrt(mean_squared_error(ya,learner.predict(x_test)))
Rsquare = r2_score(ya,learner.predict(x_test))

# %%
print("error is {} and R2 is {}".format(error,Rsquare))
# Out:
# error is 29.721646147786387 and R2 is 0.7604889622361615
