# %%
import pandas as pd

# %%
data=  pd.read_csv(r"C:\ProgramData\Ml_Data\Bmi_male_female.csv")

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# 5      Male     189     104      3
# 6      Male     147      92      5
# 7      Male     154     111      5
# 8      Male     174      90      3
# 9    Female     169     103      4
# 10     Male     195      81      2
# 11   Female     159      80      4
# 12   Female     192     101      3
# 13     Male     155      51      2
# 14     Male     191      79      2
# 15   Female     153     107      5
# 16   Female     157     110      5
# 17     Male     140     129      5
# 18     Male     144     145      5
# 19     Male     172     139      5
# 20     Male     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 23     Male     185     139      5
# 24   Female     172      67      2
# 25   Female     151      64      3
# ...

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
data.tail()
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
data.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
data["Gender"]=data["Gender"].map({"Male":0,"Female":1})

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0       0     174      96      4
# 1       0     189      87      2
# 2       1     185     110      4
# 3       1     195     104      3
# 4       0     149      61      3

# %%
data.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Gender  Height  Weight  Index
# 0         0     174      96      4
# 1         0     189      87      2
# 2         1     185     110      4
# 3         1     195     104      3
# 4         0     149      61      3
# 5         0     189     104      3
# 6         0     147      92      5
# 7         0     154     111      5
# 8         0     174      90      3
# 9         1     169     103      4
# 10        0     195      81      2
# 11        1     159      80      4
# 12        1     192     101      3
# 13        0     155      51      2
# 14        0     191      79      2
# 15        1     153     107      5
# 16        1     157     110      5
# 17        0     140     129      5
# 18        0     144     145      5
# 19        0     172     139      5
# 20        0     157     110      5
# 21        1     153     149      5
# 22        1     169      97      4
# 23        0     185     139      5
# 24        1     172      67      2
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Gender  Height  Weight  Index
# 0         0     174      96      4
# 1         0     189      87      2
# 2         1     185     110      4
# 3         1     195     104      3
# 4         0     149      61      3
# 5         0     189     104      3
# 6         0     147      92      5
# 7         0     154     111      5
# 8         0     174      90      3
# 9         1     169     103      4
# 10        0     195      81      2
# 11        1     159      80      4
# 12        1     192     101      3
# 13        0     155      51      2
# 14        0     191      79      2
# 15        1     153     107      5
# 16        1     157     110      5
# 17        0     140     129      5
# 18        0     144     145      5
# 19        0     172     139      5
# 20        0     157     110      5
# 21        1     153     149      5
# 22        1     169      97      4
# 23        0     185     139      5
# 24        1     172      67      2
# ...

# %%
real_x = data.iloc[:,0:3].values
real_y = data.iloc[:,3:4].values

# %%
# real_x
# real_y

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(real_x,real_y,test_size=.30,random_state=0)

# %%
# xtrain
# ytrain
# xtest
# ytest

# %% [markdown]
# # KNN Algorithm

# %%
# from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
trainer = KNeighborsClassifier(n_neighbors=10)

# %%
lerner = trainer.fit(xtrain,ytrain)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if __name__ == '__main__':

# %%
Ya = ytest
Yp = lerner.predict(xtest)

# %%
Yp
# Out:
# array([5, 5, 4, 5, 5, 5, 3, 5, 4, 5, 2, 4, 2, 5, 5, 3, 5, 4, 5, 5, 5, 3, 3,
#        4, 2, 1, 5, 4, 4, 2, 4, 5, 5, 5, 4, 0, 5, 4, 5, 2, 5, 4, 4, 5, 4, 2,
#        5, 2, 5, 5, 4, 4, 2, 5, 5, 3, 4, 4, 0, 4, 4, 4, 4, 1, 4, 3, 2, 3, 5,
#        5, 5, 5, 3, 4, 4, 5, 5, 5, 5, 5, 4, 3, 4, 5, 5, 3, 5, 5, 5, 4, 2, 2,
#        3, 1, 3, 1, 4, 4, 0, 3, 5, 5, 4, 3, 5, 5, 3, 5, 4, 4, 4, 5, 3, 4, 5,
#        5, 5, 4, 4, 5, 2, 5, 5, 5, 5, 5, 5, 2, 2, 4, 4, 4, 4, 3, 4, 2, 4, 2,
#        0, 5, 5, 5, 3, 3, 4, 3, 4, 4, 5, 3], dtype=int64)

# %%
Ya
# Out:
# array([[5],
#        [5],
#        [4],
#        [5],
#        [5],
#        [5],
#        [3],
#        [5],
#        [4],
#        [5],
#        [2],
#        [3],
#        [2],
#        [5],
#        [5],
#        [3],
#        [5],
#        [3],
#        [5],
#        [4],
#        [4],
#        [3],
#        [3],
#        [4],
#        [2],
#        [1],
#        [5],
#        [4],
#        [4],
#        [3],
#        [4],
#        [5],
#        [5],
#        [5],
#        [4],
#        [0],
#        [5],
#        [4],
#        [5],
#        [2],
#        [5],
#        [4],
#        [4],
#        [5],
#        [4],
#        [2],
#        [5],
#        [2],
#        [5],
#        [5],
#        [4],
#        [4],
#        [3],
#        [5],
#        [5],
#        [3],
#        [4],
#        [4],
#        [0],
#        [4],
#        [4],
#        [4],
#        [4],
#        [1],
#        [4],
#        [4],
#        [2],
#        [3],
#        [5],
#        [4],
#        [5],
# ...

# %% [markdown]
# # LinearRegression Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
lin.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred_y = lin.predict(xtest)

# %%
pred_y
# Out:
# array([[ 5.1267086 ],
#        [ 4.67821293],
#        [ 3.86820064],
#        [ 5.23915017],
#        [ 5.19746552],
#        [ 4.34288776],
#        [ 2.85728923],
#        [ 4.95546902],
#        [ 3.29796747],
#        [ 4.97856183],
#        [ 2.28329398],
#        [ 3.02786537],
#        [ 2.18671506],
#        [ 4.1951866 ],
#        [ 4.66891701],
#        [ 3.10112371],
#        [ 4.31094464],
#        [ 3.01510137],
#        [ 4.4138625 ],
#        [ 3.67320481],
#        [ 3.75406274],
#        [ 2.82548777],
#        [ 2.70914246],
#        [ 3.37262812],
#        [ 2.16510074],
#        [ 1.68583649],
#        [ 5.78997644],
#        [ 3.92906441],
#        [ 3.36104861],
#        [ 2.64495226],
#        [ 3.30925298],
#        [ 4.6379306 ],
#        [ 5.62286838],
#        [ 4.02807854],
#        [ 3.18737383],
#        [ 0.87500914],
#        [ 5.12877436],
#        [ 3.12215075],
#        [ 4.85151827],
#        [ 2.19394522],
#        [ 4.19931812],
# ...

# %%
ytest
# Out:
# array([[5],
#        [5],
#        [4],
#        [5],
#        [5],
#        [5],
#        [3],
#        [5],
#        [4],
#        [5],
#        [2],
#        [3],
#        [2],
#        [5],
#        [5],
#        [3],
#        [5],
#        [3],
#        [5],
#        [4],
#        [4],
#        [3],
#        [3],
#        [4],
#        [2],
#        [1],
#        [5],
#        [4],
#        [4],
#        [3],
#        [4],
#        [5],
#        [5],
#        [5],
#        [4],
#        [0],
#        [5],
#        [4],
#        [5],
#        [2],
#        [5],
#        [4],
#        [4],
#        [5],
#        [4],
#        [2],
#        [5],
#        [2],
#        [5],
#        [5],
#        [4],
#        [4],
#        [3],
#        [5],
#        [5],
#        [3],
#        [4],
#        [4],
#        [0],
#        [4],
#        [4],
#        [4],
#        [4],
#        [1],
#        [4],
#        [4],
#        [2],
#        [3],
#        [5],
#        [4],
#        [5],
# ...
