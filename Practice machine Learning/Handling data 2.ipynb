# %%
import pandas as pd

# %%
mydata = pd.read_csv("C:\ProgramData\Ml_Data\Car_sales.csv")

# %%
mydata.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# Encoding

# %%
mydata.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
mydata.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
mydata.shape
# Out:
# (157, 15)

# %%
mydata.count()
# Out:
# Manufacturer           157
# Model                  157
# Sales in thousands     157
# 4-year resale value    157
# Vehicle type           157
# Price in thousands     157
# Engine size            157
# Horsepower             157
# Wheelbase              157
# Width                  157
# Length                 157
# Curb weight            157
# Fuel capacity          157
# Fuel efficiency        157
# Latest Launch          157
# dtype: int64

# %%
import numpy as np

# %%
len(np.unique(mydata.iloc[:,0]))
# Out:
# 30

# %%
car = mydata.iloc[:,0]
car[:5]
# Out:
# 0    Acura
# 1    Acura
# 2    Acura
# 3    Acura
# 4    Audi
# Name: Manufacturer, dtype: object

# %%
car.value_counts()[:10]
# Out:
# Dodge            11
# Ford             11
# Chevrolet         9
# Toyota            9
# Mercedes-Benz     9
# Chrysler          7
# Mitsubishi        7
# Nissan            7
# Volkswagen        6
# Mercury           6
# Name: Manufacturer, dtype: int64

# %%
import seaborn as sb
from matplotlib import pyplot as plt

# %% [markdown]
# # preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
 sb.countplot("Manufacturer",data=mydata)

# %%
 plt.show()

# %%
mydata.iloc[:,0]=le.fit_transform(mydata.iloc[:,0])

# %%
mydata
# Out:
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0               0  Integra                        16.919               16.36
# 1               0  TL                             39.384              19.875
# 2               0  CL                             14.114              18.225
# 3               0  RL                              8.588              29.725
# 4               1  A4                             20.397              22.255
# 5               1  A6                             18.780              23.555
# 6               1  A8                              1.380                  39
# 7               2  323i                           19.747                   .
# 8               2  328i                            9.231              28.675
# 9               2  528i                           17.527              36.125
# 10              3  Century                        91.561              12.475
# ...
