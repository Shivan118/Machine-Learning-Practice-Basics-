# %%
import pandas as pd

# %%
mydata = pd.read_csv("C:\ProgramData\Ml_Data\Titanic_Data.csv")

# %%
mydata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
mydata.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mydata.notnull()
# Out:
#     PassengerId Survived Pclass  Name   Sex    Age SibSp Parch Ticket  Fare  \
# 0          True     True   True  True  True   True  True  True   True  True
# 1          True     True   True  True  True   True  True  True   True  True
# 2          True     True   True  True  True   True  True  True   True  True
# 3          True     True   True  True  True   True  True  True   True  True
# 4          True     True   True  True  True   True  True  True   True  True
# 5          True     True   True  True  True  False  True  True   True  True
# 6          True     True   True  True  True   True  True  True   True  True
# 7          True     True   True  True  True   True  True  True   True  True
# 8          True     True   True  True  True   True  True  True   True  True
# 9          True     True   True  True  True   True  True  True   True  True
# 10         True     True   True  True  True   True  True  True   True  True
# ...

# %%
x=mydata
xm=mydata.dropna()
print("shape of x {} and shape of xm {}".format(x.shape,xm.shape))
# Out:
# shape of x (891, 12) and shape of xm (183, 12)

# %%
x = mydata
xm = mydata.dropna(how='all')
print("shape of x {} and shape of xm {}".format(x.shape,xm.shape))
# Out:
# shape of x (891, 12) and shape of xm (891, 12)

# %%
#x = mydata
#xm = mydata.dropna(thresh=5)
#print("shape of x {} and shape of xm {}".format(x.shape,xm.shape))

# %%
xm = x.dropna(thresh=5)

# %%
#xm.shape
# Out:
# (891, 12)

# %%
mydata.dropna(inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
mydata.shape
# Out:
# (891, 12)

# %%
mydata.fillna(0)             #fill the data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
mydata.fillna(mydata["Parch"].mean(),inplace=True)

# %%
mydata.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # groupby

# %%
mydata.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mydata.groupby(["Sex"])

# %%
mydata.groupby(["Sex"]).mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  23.268231  0.694268  0.649682
# male     454.147314  0.188908  2.389948  24.205351  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
mydata.groupby(["Survived","Sex"]).mean()
# Out:
#                  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived Sex
# 0        female   434.851852  2.851852  19.870211  1.209877  1.037037
#          male     449.121795  2.476496  24.409641  0.440171  0.207265
# 1        female   429.699571  1.918455  24.449517  0.515021  0.515021
#          male     475.724771  2.018349  23.328216  0.385321  0.357798
#
#                       Fare
# Survived Sex
# 0        female  23.024385
#          male    21.960993
# 1        female  51.938573
#          male    40.821484

# %%
mydata.groupby(["Survived","Sex"]).max()
# Out:
#                   Age      Fare                                          Name  \
# Survived Sex
# 0        female  57.0  151.5500                         Zabour, Miss. Thamine
#          male    74.0  263.0000                   van Melkebeke, Mr. Philemon
# 1        female  63.0  512.3292  de Messemaeker, Mrs. Guillaume Joseph (Emma)
#          male    80.0  512.3292                       de Mulder, Mr. Theodore
#
#                  Parch  PassengerId  Pclass  SibSp      Ticket
# Survived Sex
# 0        female      6          889       3      8  W./C. 6609
#          male        5          891       3      8   WE/P 5735
# 1        female      5          888       3      4   WE/P 5735
#          male        2          890       3      4   SW/PP 751

# %%
mydata.head()  # FINAL HANDLING MISSING VALUES.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare     Cabin Embarked
# 0      0         A/5 21171   7.2500  0.381594        S
# 1      0          PC 17599  71.2833       C85        C
# 2      0  STON/O2. 3101282   7.9250  0.381594        S
# 3      0            113803  53.1000      C123        S
# ...

# %%
from sklearn prerocessing
